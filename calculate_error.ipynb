# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('Salary_data.csv')
data.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df=data[['Age','Salary']]
df.head()
# Out:
#     Age    Salary
# 0  32.0   90000.0
# 1  28.0   65000.0
# 2  45.0  150000.0
# 3  36.0   60000.0
# 4  52.0  200000.0

# %%
data.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
df=data.sample(1000)
df.head()
# Out:
#        Age  Gender  Education Level                  Job Title  \
# 1374  54.0    Male              PhD  Software Engineer Manager
# 2523  39.0    Male  Master's Degree  Software Engineer Manager
# 5913  36.0  Female              PhD         Research Scientist
# 4040  35.0  Female  Master's Degree          Marketing Manager
# 3982  44.0    Male              PhD             Data Scientist
#
#       Years of Experience    Salary
# 1374                 17.0  195000.0
# 2523                 14.0  142360.0
# 5913                 12.0  170000.0
# 4040                 10.0  110000.0
# 3982                 15.0  150000.0

# %%
x=df[['Age']]
y=df.Salary

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression ()
linear_model.fit(x,y)
# Out:
# LinearRegression()

# %%
linear_model.intercept_
# Out:
# -57063.23997856969

# %%
linear_model.coef_
# Out:
# array([5184.17241937])

# %%
agenw=45
linear_model.predict([[agenw]])
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([176224.51889286])

# %%
#Mean Squared Error

# %%
ypred=linear_model.predict(x)

# %%
x.head()
# Out:
#        Age
# 1374  54.0
# 2523  39.0
# 5913  36.0
# 4040  35.0
# 3982  44.0

# %%
y
# Out:
# 1374    195000.0
# 2523    142360.0
# 5913    170000.0
# 4040    110000.0
# 3982    150000.0
#           ...
# 4279    119000.0
# 6111     60000.0
# 6195    170000.0
# 2386    101332.0
# 2452    134858.0
# Name: Salary, Length: 1000, dtype: float64

# %%
ypred
# Out:
# array([222882.07066715, 145119.48437667, 129566.96711858, 124382.79469921,
#        171040.3464735 ,  67356.89808619,  82909.41534429,  62172.72566683,
#         93277.76018302, 108830.27744112,  93277.76018302,  62172.72566683,
#         82909.41534429, 191777.03615096, 103646.10502175, 139935.31195731,
#        181408.69131223, 176224.51889286, 171040.3464735 , 171040.3464735 ,
#        108830.27744112,  88093.58776366, 103646.10502175, 155487.8292154 ,
#         93277.76018302, 176224.51889286,  82909.41534429,  82909.41534429,
#         88093.58776366,  67356.89808619,  67356.89808619,  82909.41534429,
#        103646.10502175,  88093.58776366, 222882.07066715, 139935.31195731,
#         88093.58776366, 145119.48437667, 145119.48437667, 108830.27744112,
#        171040.3464735 , 108830.27744112,  88093.58776366,  72541.07050556,
#         82909.41534429, 114014.44986048,  88093.58776366, 160672.00163477,
# ...

# %%
error=y-ypred
ypred
# Out:
# array([222882.07066715, 145119.48437667, 129566.96711858, 124382.79469921,
#        171040.3464735 ,  67356.89808619,  82909.41534429,  62172.72566683,
#         93277.76018302, 108830.27744112,  93277.76018302,  62172.72566683,
#         82909.41534429, 191777.03615096, 103646.10502175, 139935.31195731,
#        181408.69131223, 176224.51889286, 171040.3464735 , 171040.3464735 ,
#        108830.27744112,  88093.58776366, 103646.10502175, 155487.8292154 ,
#         93277.76018302, 176224.51889286,  82909.41534429,  82909.41534429,
#         88093.58776366,  67356.89808619,  67356.89808619,  82909.41534429,
#        103646.10502175,  88093.58776366, 222882.07066715, 139935.31195731,
#         88093.58776366, 145119.48437667, 145119.48437667, 108830.27744112,
#        171040.3464735 , 108830.27744112,  88093.58776366,  72541.07050556,
#         82909.41534429, 114014.44986048,  88093.58776366, 160672.00163477,
# ...

# %%
error2=np.power(error,2)
error2
# Out:
# 1374    7.774099e+08
# 2523    7.614754e+06
# 5913    1.634830e+09
# 4040    2.068648e+08
# 3982    4.426962e+08
#             ...
# 4279    4.382873e+08
# 6111    1.572784e+08
# 6195    2.580780e+09
# 2386    5.313391e+08
# 2452    2.577910e+07
# Name: Salary, Length: 1000, dtype: float64

# %%
mse=np.mean(error2)
print(f'MSE : {mse:.2f}')
# Out:
# MSE : 1246932345.55

# %%
#syntax : mean_squared_error(yactual,ypredicted)

# %%
ypred

# %%
mse=mean_squared_error(y,ypred)
print(f'MSE : {mse:.2f}')
# Out:
# MSE : 1246932345.55

# %%
#Root_Mean_Squared_error
rmse=np.sqrt(mse)
print(f'RMSE : {rmse:.2f}')
# Out:
# RMSE : 35311.93

# %%
#Mean Absolute Error
mae=mean_absolute_error(y, ypred)
print(f'MAE : {mae:.2f}')
# Out:
# MAE : 28174.35

# %%
#Mean Absolute Percentage Error
mape=mean_absolute_percentage_error(y, ypred)
mape=mape*100
print(f'MAPE : {mape:.2f}%')
# Out:
# MAPE : 34.37%

# %%
# R2_score
r2=r2_score(y,ypred)
print(f'R2 - score : {r2:.2f}')
# Out:
# R2 - score : 0.54

# %% [markdown]
# Train
#
# X-prediction : y ypred
# Testing

# %%
Testing-dont give the data of training

# %%
Data
     -training data ("training data are greater than testing data")
     -testing data

# %%
Data-
   x,y
  xtrain, xtest,          ytrain, ytest

# %%
#once again

# %%
data=pd.read_csv('Salary_data.csv')
data.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
data.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
# Create x and y
x=data[['Age']]
y=data.Salary

# %%
x
# Out:
#        Age
# 0     32.0
# 1     28.0
# 2     45.0
# 3     36.0
# 4     52.0
# ...    ...
# 6699  49.0
# 6700  32.0
# 6701  30.0
# 6702  46.0
# 6703  26.0
#
# [6698 rows x 1 columns]

# %%
y
# Out:
# 0        90000.0
# 1        65000.0
# 2       150000.0
# 3        60000.0
# 4       200000.0
#           ...
# 6699    200000.0
# 6700     50000.0
# 6701     55000.0
# 6702    140000.0
# 6703     35000.0
# Name: Salary, Length: 6698, dtype: float64

# %% [raw]
# #split to train and test
# xtrain, xtest,ytrain ,ytest=train_test_split(x,y, test_size=0.2, random_state=7)
# #test_size kati percentage data lai testing garney vnne
# #random_state= to hold data for training and testing untill it is changed

# %%
xtrain
# Out:
#        Age
# 2929  46.0
# 4258  27.0
# 374   44.0
# 1132  34.0
# 1779  48.0
# ...    ...
# 5704  26.0
# 2553  31.0
# 539   27.0
# 1222  42.0
# 4275  29.0
#
# [5358 rows x 1 columns]

# %%
ytrain
# Out:
# 2929    150729.0
# 4258     36000.0
# 374     150000.0
# 1132    195000.0
# 1779    185000.0
#           ...
# 5704     55000.0
# 2553    100052.0
# 539     140000.0
# 1222    180000.0
# 4275     71000.0
# Name: Salary, Length: 5358, dtype: float64

# %%
model=LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
#Evaluation
xtest      ytest        ypredicition

# %%
yprediction=model.predict(xtest)

# %%
yprediction
# Out:
# array([ 96864.3975814 ,  91857.04807984, 136923.19359391, ...,
#         76834.99957515,  96864.3975814 , 106879.09658453])

# %%
xtest      ytest        ypredicition

# %%
mae=mean_absolute_error(ytest, yprediction)
print(f'MAE : {mae:.2f}')
# Out:
# MAE : 28870.10

# %%
#assignment 
X=data[['Age', 'Years of Experience']]
