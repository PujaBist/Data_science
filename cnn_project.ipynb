# %%
pip install tensorflow
# Out:
# ...
#    ---------------------------------------- 0.0/376.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/376.0 MB ? eta -:--:--
#    ---------------------------------------- 0.8/376.0 MB 2.8 MB/s eta 0:02:14
#    ---------------------------------------- 1.8/376.0 MB 3.9 MB/s eta 0:01:37
#    ---------------------------------------- 2.9/376.0 MB 4.0 MB/s eta 0:01:34
#    ---------------------------------------- 3.7/376.0 MB 4.0 MB/s eta 0:01:33
#     --------------------------------------- 4.7/376.0 MB 4.2 MB/s eta 0:01:29
#     --------------------------------------- 5.5/376.0 MB 4.1 MB/s eta 0:01:31
#     --------------------------------------- 6.6/376.0 MB 4.2 MB/s eta 0:01:29
#     --------------------------------------- 7.3/376.0 MB 4.2 MB/s eta 0:01:28
#     --------------------------------------- 8.1/376.0 MB 4.2 MB/s eta 0:01:28
#     --------------------------------------- 8.9/376.0 MB 4.2 MB/s eta 0:01:29
# ...

# %%
from  tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Conv2D, MaxPooling2D,Flatten

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

# %%
# Data Genarator
data_gen=[ImageDataGenerator(rescale=1./255)

# %%
traindata=data_gen.flow_from_directory(
    'train_data', # floder name of trainig data
    target_size=(64,64),
    batch_size=32,
    class_mode='binary' , # if multiclass then wirte class_mode=categorical
    subset='training'
    }

# %%
1000row xh if 

1 row weight update
1 row weight update

1000 rows sakye paxi 1 epochs
batch = 32 rows

# %%
cnn_model=Sequential([
    Input(Shape=(64,64, 3)),# image of 64 * 64 RGB=3
    Conv2D(16,(3,3),activation='relu'),# 16 ota filter of size 3 * 3
    MAxPooling2D((2,2)),
    Conv2D(32,(3,3),activation='relu'),
    MAxPooling2D((2,2)),
    Flatten()
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid'), # for binary classification
          # Dense(4, activation='softmax'), # multiclass ho vney jati target class xh tati ota node
    
])

# %%
Dense(1, activation='sigmoid'), for binary classification
sigmoid [0-0.5]=0
else 1 hunch output

# %%
softmax -    rain  sunny cloud  shine yi sabae class ko prob niklach then jasko prob max xh tyo target class nai predict hunch

# %%
#Compile
cnn_model.compile(optimizer= 'adam', loss='binary_crossentropy , metrics=['accuracy']) # loss='categorical_crossentropy'

# %%
# fit
cnn_model.fit(traindata, epochs=20)

# %%
testdata=data_gen.flow_from_directory(
    'test_data', # floder name of trainig data
    target_size=(64,64),
    batch_size=32,
    class_mode='binary' , # if multiclass then wirte class_mode=categorical
    subset='training'
    }

# %%
#for evaluation
cnn_model.evaluate(testdata)
