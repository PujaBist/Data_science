# %%
from sklearn.linear_model import LinearRegression
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error,r2_score
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("Salary_Data.csv")
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.isnull().sum()                                         # to check if the nulll value exist or not
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()                                         # to check if the nulll value exist or not
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
# Features and target
x = df[['Age', 'Years of Experience']]
y = df['Salary']

# %%
x
# Out:
#        Age  Years of Experience
# 0     32.0                  5.0
# 1     28.0                  3.0
# 2     45.0                 15.0
# 3     36.0                  7.0
# 4     52.0                 20.0
# ...    ...                  ...
# 6699  49.0                 20.0
# 6700  32.0                  3.0
# 6701  30.0                  4.0
# 6702  46.0                 14.0
# 6703  26.0                  1.0
#
# [6698 rows x 2 columns]

# %%
y
# Out:
# 0        90000.0
# 1        65000.0
# 2       150000.0
# 3        60000.0
# 4       200000.0
#           ...
# 6699    200000.0
# 6700     50000.0
# 6701     55000.0
# 6702    140000.0
# 6703     35000.0
# Name: Salary, Length: 6698, dtype: float64

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=32)

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X)
print(predictions)
# Out:
# [ 89968.27708896  78756.4039208  158303.3489757  ...  84362.34050488
#  147436.3955148   64037.18616808]

# %%
print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
# Out:
# Intercept: 100519.38459857508
# Coefficients: [-1753.67229227  9113.28116863]

# %%
ypred = model.predict(xtest)

# %%
ypred
# Out:
# array([ 73495.38704397, 144992.883808  ,  73150.46733671, ...,
#         86116.01279715, 111702.18401077,  64727.02558261])

# %%
mae = mean_absolute_error(ytest, ypred)
print(f"MAE:{mae:.2f}")
# Out:
# MAE:24676.50

# %%
# R-squared (Coefficient of Determination)
r2 = r2_score(ytest, ypred)
print(f"r2_Score:{mae:.2f}")
# Out:
# r2_Score:24676.50

# %%
print("True values:", ytest.values)
print("Predicted values:", ypred)
# Out:
# True values: [ 50000. 125000.  38000. ...  70000. 185000.  45000.]
# Predicted values: [ 73495.38704397 144992.883808    73150.46733671 ...  86116.01279715
#  111702.18401077  64727.02558261]

# %%
error = ytest - ypred

# %%
error
# Out:
# 6443   -23495.387044
# 4334   -19992.883808
# 4564   -35150.467337
# 4375   -26249.059336
# 1515    25051.488282
#             ...
# 3047   -68593.016953
# 4297   -15835.230550
# 3494   -16116.012797
# 818     73297.815989
# 6371   -19727.025583
# Name: Salary, Length: 1340, dtype: float64

# %%
# Mean Absolute Error
mae = mean_absolute_error(ytest, ypred)

# Mean Squared Error
mse = mean_squared_error(ytest, ypred)

# Root Mean Squared Error
rmse = np.sqrt(mse)

# R-squared
r2 = r2_score(ytest, ypred)

print(f"MAE: {mae:.2f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R-squared: {r2:.4f}")
# Out:
# MAE: 24676.50
# MSE: 945414989.74
# RMSE: 30747.60
# R-squared: 0.6590
