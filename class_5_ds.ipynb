# %%
import pandas as pd
https://github.com/PujaBist/Data_science.git

# %%
data=pd.read_csv('/test.csv')

# %%
print(data)
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
#unique()
data['Pclass'].unique()
# Out:
# array([3, 2, 1])

# %%
data['Embarked'].unique()
# Out:
# array(['Q', 'S', 'C'], dtype=object)

# %%
data['Age'].describe()
# Out:
# count    332.000000
# mean      30.272590
# std       14.181209
# min        0.170000
# 25%       21.000000
# 50%       27.000000
# 75%       39.000000
# max       76.000000
# Name: Age, dtype: float64

# %%
data['Age'].median()
# Out:
# 27.0

# %%
data['Age'].mode() #=> highest frequency or most repeated value
# Out:
# 0    21.0
# 1    24.0
# Name: Age, dtype: float64

# %%
data.loc[5]
# Out:
# PassengerId                           897
# Pclass                                  3
# Name           Svensson, Mr. Johan Cervin
# Sex                                  male
# Age                                  14.0
# SibSp                                   0
# Parch                                   0
# Ticket                               7538
# Fare                                9.225
# Cabin                                 NaN
# Embarked                                S
# Name: 5, dtype: object

# %%
data.loc[5:10]
# Out:
#     PassengerId  Pclass                                       Name     Sex  \
# 5           897       3                 Svensson, Mr. Johan Cervin    male
# 6           898       3                       Connolly, Miss. Kate  female
# 7           899       2               Caldwell, Mr. Albert Francis    male
# 8           900       3  Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9           901       3                    Davies, Mr. John Samuel    male
# 10          902       3                           Ilieff, Mr. Ylio    male
#
#      Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 5   14.0      0      0       7538   9.2250   NaN        S
# 6   30.0      0      0     330972   7.6292   NaN        Q
# 7   26.0      1      1     248738  29.0000   NaN        S
# 8   18.0      0      0       2657   7.2292   NaN        C
# 9   21.0      2      0  A/4 48871  24.1500   NaN        S
# 10   NaN      0      0     349220   7.8958   NaN        S

# %%
#Display those rows /data whose age =40

# %%
data[data['Age']==40]



#data.Age
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex  Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
data.query('Age==40')
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex  Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          418 non-null    int64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 36.1+ KB

# %%
Exploratory data Analysis
# Out:
#   File "<ipython-input-25-ead4361bb5be>", line 1
#     Exploratory data Analysis
#                 ^
# SyntaxError: invalid syntax

# %%
dat=pd.read_csv('/Salary_Data.csv')
print(dat)
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
dat['Education Level'].unique()
#=>issues are
1)missing value=> nan, Not a number
2)"Bachelor's", "Bachelor's Degree" both are same
# Out:
# array(["Bachelor's", "Master's", 'PhD', nan, "Bachelor's Degree",
#        "Master's Degree", 'High School', 'phD'], dtype=object)

# %%
#issues
1.Missing Values(nan=>not a number, value xaen)
2.non-standard/Inconsistency


#Read - cleaning

# %%
#missing values(.isnull())
dat.isnull().sum() #=>sum le sabae value add garna milxich
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
dat[dat.isnull().any(axis=1)]
# any=> yo le auta mtr missing value  xh vaney pani dinch
# Out:
#        Age  Gender    Education Level            Job Title  \
# 172    NaN     NaN                NaN                  NaN
# 260    NaN     NaN                NaN                  NaN
# 2011  27.0    Male                NaN            Developer
# 3136  31.0    Male    Master's Degree  Full Stack Engineer
# 5247  26.0  Female  Bachelor's Degree             Social M
# 6455  36.0    Male  Bachelor's Degree       Sales Director
#
#       Years of Experience    Salary
# 172                   NaN       NaN
# 260                   NaN       NaN
# 2011                  7.0  100000.0
# 3136                  8.0       NaN
# 5247                  NaN       NaN
# 6455                  6.0       NaN

# %%
#all
#all=> it gives those value in which all rows value is zero
dat[dat.isnull().all(axis=1)]
# Out:
#      Age Gender Education Level Job Title  Years of Experience  Salary
# 172  NaN    NaN             NaN       NaN                  NaN     NaN
# 260  NaN    NaN             NaN       NaN                  NaN     NaN

# %%
#axis=0 row
#axis=1 column

# %%
from os import remove
#Handling missing values
FILL
=> WE can fill through mean(),median(),mode()
=> forwardfill(), backwardfill()
=>nearestvalue() =>max jo sng milyo teskae value le replace gardiney
Drop-
  => if any coulmn have , most of the values are missing(nan)-remove column
  =>remove that row BECAUSE WE HAVE MANY DATA

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6704 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6702 non-null   float64
#  1   Gender               6702 non-null   object
#  2   Education Level      6701 non-null   object
#  3   Job Title            6702 non-null   object
#  4   Years of Experience  6701 non-null   float64
#  5   Salary               6699 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 314.4+ KB

# %%
dat.describe()
# Out:
#                Age  Years of Experience         Salary
# count  6702.000000          6701.000000    6699.000000
# mean     33.620859             8.094687  115326.964771
# std       7.614633             6.059003   52786.183911
# min      21.000000             0.000000     350.000000
# 25%      28.000000             3.000000   70000.000000
# 50%      32.000000             7.000000  115000.000000
# 75%      38.000000            12.000000  160000.000000
# max      62.000000            34.000000  250000.000000

# %%
dat.dropna() #=>it removes those data which have nan
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
dat.shape #=> after drop again it delete orginal data set
# Out:
# (6704, 6)

# %%
dat=dat.dropna() # yastw nagrney because it earse delete orginal data if we need in future we have no option

# %%
dat.dropna(inplace=True) # it chnges in orginal data
# Out:
# <ipython-input-45-cb5adaacb6f4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat.dropna(inplace=True)

# %%
df=dat.dropna()
print(df)
print(dat)
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df.shape
# Out:
# (6698, 6)

# %%
dat.shape
# Out:
# (6698, 6)

# %%
#for editing  particular  data in dataset
dat.at[2,'Job Title']
# Out:
# 'Senior Manager'

# %%
#for add particular  data in dataset
dat.at[2,'Job Title']='SeniroM'
print(dat)
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD                SeniroM
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
#plots

# %%
#Barplot
#histogram
#scatterplot
#boxplot

# %%
#for visualization
#Matplotlib
#Seaborn

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
#Histogram : Single numeric varible
# syntax : plt.hist(column_name)

# %%
#Histogram is uses for see distribution of data

# %%
plt.hist(dat.Age)
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Counts')
plt.show()

# %%
#Bins
20-25 :
25-30 :

# %%
plt.hist(dat.Age,bins=5)
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Counts')
plt.show()

# %%
Load->EDA->CLEAN->EDA
# Out:
#   File "<ipython-input-65-9535a291d269>", line 1
#     Load->EDA->CLEAN->
#         ^
# SyntaxError: invalid syntax

# %%
help(plt.hist)
# Out:
# Help on function hist in module matplotlib.pyplot:
#
# hist(x: 'ArrayLike | Sequence[ArrayLike]', bins: 'int | Sequence[float] | str | None' = None, *, range: 'tuple[float, float] | None' = None, density: 'bool' = False, weights: 'ArrayLike | None' = None, cumulative: 'bool | float' = False, bottom: 'ArrayLike | float | None' = None, histtype: "Literal['bar', 'barstacked', 'step', 'stepfilled']" = 'bar', align: "Literal['left', 'mid', 'right']" = 'mid', orientation: "Literal['vertical', 'horizontal']" = 'vertical', rwidth: 'float | None' = None, log: 'bool' = False, color: 'ColorType | Sequence[ColorType] | None' = None, label: 'str | Sequence[str] | None' = None, stacked: 'bool' = False, data=None, **kwargs) -> 'tuple[np.ndarray | list[np.ndarray], np.ndarray, BarContainer | Polygon | list[BarContainer | Polygon]]'
#     Compute and plot a histogram.
#
#     This method uses `numpy.histogram` to bin the data in *x* and count the
# ...
